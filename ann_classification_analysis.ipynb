# %%
import numpy as np
import pandas as pd

try:
    import theano
except:
    # !pip install Theano
try:
    import keras
except:
    # !pip install keras
try:
    import tensorflow
except:
    # !pip install tensorflow
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# Out:
# WARNING (theano.configdefaults): g++ not available, if using conda: `conda install m2w64-toolchain`
# C:\Users\ahmet\anaconda3\lib\site-packages\theano\configdefaults.py:560: UserWarning: DeprecationWarning: there is no c++ compiler.This is deprecated and with Theano 0.11 a c++ compiler will be mandatory
#   warnings.warn("DeprecationWarning: there is no c++ compiler."
# WARNING (theano.configdefaults): g++ not detected ! Theano will be unable to execute optimized C-implementations (for both CPU and GPU) and will default to Python implementations. Performance will be severely degraded. To remove this warning, set Theano flags cxx to an empty string.
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.
# Requirement already satisfied: keras in c:\users\ahmet\anaconda3\lib\site-packages (2.12.0)
# Collecting tensorflow
#   Using cached tensorflow-2.12.0-cp310-cp310-win_amd64.whl (1.9 kB)
# Collecting tensorflow-intel==2.12.0
#   Using cached tensorflow_intel-2.12.0-cp310-cp310-win_amd64.whl (272.8 MB)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\ahmet\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\ahmet\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ahmet\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\ahmet\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.23.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\ahmet\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.54.2)
# Requirement already satisfied: packaging in c:\users\ahmet\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (22.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in c:\users\ahmet\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\ahmet\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.4.0)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in c:\users\ahmet\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\ahmet\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.4.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\ahmet\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.14.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\ahmet\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.6.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\ahmet\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\ahmet\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.16.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in c:\users\ahmet\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.3)
# Requirement already satisfied: jax>=0.3.15 in c:\users\ahmet\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.12)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\ahmet\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.7.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\ahmet\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.31.0)
# Requirement already satisfied: setuptools in c:\users\ahmet\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (65.6.3)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\ahmet\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (16.0.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\ahmet\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (23.5.26)
# Requirement already satisfied: numpy<1.24,>=1.22 in c:\users\ahmet\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.23.5)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\ahmet\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0->tensorflow) (0.38.4)
# Requirement already satisfied: ml-dtypes>=0.1.0 in c:\users\ahmet\anaconda3\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (0.2.0)
# Requirement already satisfied: scipy>=1.7 in c:\users\ahmet\anaconda3\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (1.10.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\ahmet\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.2.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ahmet\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.4.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\ahmet\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.20.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\ahmet\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.0.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\ahmet\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.28.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\ahmet\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.7.1)
# Requirement already satisfied: urllib3<2.0 in c:\users\ahmet\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.26.14)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\ahmet\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\ahmet\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\ahmet\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\ahmet\anaconda3\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ahmet\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ahmet\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ahmet\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\ahmet\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\ahmet\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\ahmet\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.2.2)
# Installing collected packages: tensorflow-intel, tensorflow
# Successfully installed tensorflow-2.12.0 tensorflow-intel-2.12.0

# %%
import pandas as pd

churn_data = pd.read_csv('C:/Users/ahmet/pandas/Churn_Modelling.csv',index_col='RowNumber')

# %%
churn_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 1 to 10000
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10000 non-null  int64
#  1   Surname          10000 non-null  object
#  2   CreditScore      10000 non-null  int64
#  3   Geography        10000 non-null  object
#  4   Gender           10000 non-null  object
#  5   Age              10000 non-null  int64
#  6   Tenure           10000 non-null  int64
#  7   Balance          10000 non-null  float64
#  8   NumOfProducts    10000 non-null  int64
#  9   HasCrCard        10000 non-null  int64
#  10  IsActiveMember   10000 non-null  int64
#  11  EstimatedSalary  10000 non-null  float64
#  12  Exited           10000 non-null  int64
# dtypes: float64(2), int64(8), object(3)
# memory usage: 1.1+ MB

# %%
churn_data.describe()
# Out:
#          CustomerId   CreditScore           Age        Tenure        Balance  \
# count  1.000000e+04  10000.000000  10000.000000  10000.000000   10000.000000
# mean   1.569094e+07    650.528800     38.921800      5.012800   76485.889288
# std    7.193619e+04     96.653299     10.487806      2.892174   62397.405202
# min    1.556570e+07    350.000000     18.000000      0.000000       0.000000
# 25%    1.562853e+07    584.000000     32.000000      3.000000       0.000000
# 50%    1.569074e+07    652.000000     37.000000      5.000000   97198.540000
# 75%    1.575323e+07    718.000000     44.000000      7.000000  127644.240000
# max    1.581569e+07    850.000000     92.000000     10.000000  250898.090000
#
#        NumOfProducts    HasCrCard  IsActiveMember  EstimatedSalary  \
# count   10000.000000  10000.00000    10000.000000     10000.000000
# mean        1.530200      0.70550        0.515100    100090.239881
# std         0.581654      0.45584        0.499797     57510.492818
# min         1.000000      0.00000        0.000000        11.580000
# 25%         1.000000      0.00000        0.000000     51002.110000
# 50%         1.000000      1.00000        1.000000    100193.915000
# 75%         2.000000      1.00000        1.000000    149388.247500
# max         4.000000      1.00000        1.000000    199992.480000
#
#              Exited
# count  10000.000000
# mean       0.203700
# std        0.402769
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
churn_data.head()
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602  Hargrave          619    France  Female   42       2
# 2            15647311      Hill          608     Spain  Female   41       1
# 3            15619304      Onio          502    France  Female   42       8
# 4            15701354      Boni          699    France  Female   39       1
# 5            15737888  Mitchell          850     Spain  Female   43       2
#
#              Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber
# 1               0.00              1          1               1
# 2           83807.86              1          0               1
# 3          159660.80              3          1               0
# 4               0.00              2          0               0
# 5          125510.82              1          1               1
#
#            EstimatedSalary  Exited
# RowNumber
# 1                101348.88       1
# 2                112542.58       0
# 3                113931.57       1
# 4                 93826.63       0
# 5                 79084.10       0

# %%
churn_data.drop(['CustomerId','Surname'],axis=1,inplace=True)

# %%
churn_data.head()
# Out:
#            CreditScore Geography  Gender  Age  Tenure    Balance  \
# RowNumber
# 1                  619    France  Female   42       2       0.00
# 2                  608     Spain  Female   41       1   83807.86
# 3                  502    France  Female   42       8  159660.80
# 4                  699    France  Female   39       1       0.00
# 5                  850     Spain  Female   43       2  125510.82
#
#            NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# RowNumber
# 1                      1          1               1        101348.88       1
# 2                      1          0               1        112542.58       0
# 3                      3          1               0        113931.57       1
# 4                      2          0               0         93826.63       0
# 5                      1          1               1         79084.10       0

# %%
Geography_dummies = pd.get_dummies(prefix='Geo',data=churn_data,columns=['Geography'])

# %%
Geography_dummies.head()
# Out:
#            CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  \
# RowNumber
# 1                  619  Female   42       2       0.00              1
# 2                  608  Female   41       1   83807.86              1
# 3                  502  Female   42       8  159660.80              3
# 4                  699  Female   39       1       0.00              2
# 5                  850  Female   43       2  125510.82              1
#
#            HasCrCard  IsActiveMember  EstimatedSalary  Exited  Geo_France  \
# RowNumber
# 1                  1               1        101348.88       1           1
# 2                  0               1        112542.58       0           0
# 3                  1               0        113931.57       1           1
# 4                  0               0         93826.63       0           1
# 5                  1               1         79084.10       0           0
#
#            Geo_Germany  Geo_Spain
# RowNumber
# 1                    0          0
# 2                    0          1
# 3                    0          0
# 4                    0          0
# 5                    0          1

# %%
Gender_dummies = Geography_dummies.replace(to_replace={'Gender': {'Female': 1,'Male':0}})

# %%
Gender_dummies.head()
# Out:
#            CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  \
# RowNumber
# 1                  619       1   42       2       0.00              1
# 2                  608       1   41       1   83807.86              1
# 3                  502       1   42       8  159660.80              3
# 4                  699       1   39       1       0.00              2
# 5                  850       1   43       2  125510.82              1
#
#            HasCrCard  IsActiveMember  EstimatedSalary  Exited  Geo_France  \
# RowNumber
# 1                  1               1        101348.88       1           1
# 2                  0               1        112542.58       0           0
# 3                  1               0        113931.57       1           1
# 4                  0               0         93826.63       0           1
# 5                  1               1         79084.10       0           0
#
#            Geo_Germany  Geo_Spain
# RowNumber
# 1                    0          0
# 2                    0          1
# 3                    0          0
# 4                    0          0
# 5                    0          1

# %%
churn_data_encoded = Gender_dummies

# %%
sns.countplot(y=churn_data_encoded.Exited ,data=churn_data_encoded)
plt.xlabel("Count of each Target class")
plt.ylabel("Target classes")
plt.show()

# %%
churn_data_encoded.hist(figsize=(15,12),bins = 15)
plt.title("Features Distribution")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15,15))
p=sns.heatmap(churn_data_encoded.corr(), annot=True,cmap='RdYlGn',center=0)

# %%
fig,ax = plt.subplots(nrows = 4, ncols=3, figsize=(30,30))
row = 0
col = 0
for i in range(len(churn_data_encoded.columns) -1):
    if col > 2:
        row += 1
        col = 0
    axes = ax[row,col]
    sns.boxplot(x = churn_data_encoded['Exited'], y = churn_data_encoded[churn_data_encoded.columns[i]],ax = axes)
    col += 1
plt.tight_layout()
# plt.title("Individual Features by Class")
plt.show()

# %%
X = churn_data_encoded.drop(['Exited'],axis=1)
y = churn_data_encoded.Exited

# %%
X.head(10)
# Out:
#            CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  \
# RowNumber
# 1                  619       1   42       2       0.00              1
# 2                  608       1   41       1   83807.86              1
# 3                  502       1   42       8  159660.80              3
# 4                  699       1   39       1       0.00              2
# 5                  850       1   43       2  125510.82              1
# 6                  645       0   44       8  113755.78              2
# 7                  822       0   50       7       0.00              2
# 8                  376       1   29       4  115046.74              4
# 9                  501       0   44       4  142051.07              2
# 10                 684       0   27       2  134603.88              1
#
#            HasCrCard  IsActiveMember  EstimatedSalary  Geo_France  \
# RowNumber
# 1                  1               1        101348.88           1
# 2                  0               1        112542.58           0
# 3                  1               0        113931.57           1
# 4                  0               0         93826.63           1
# 5                  1               1         79084.10           0
# 6                  1               0        149756.71           0
# 7                  1               1         10062.80           1
# 8                  1               0        119346.88           0
# 9                  0               1         74940.50           1
# 10                 1               1         71725.73           1
#
#            Geo_Germany  Geo_Spain
# RowNumber
# 1                    0          0
# 2                    0          1
# 3                    0          0
# 4                    0          0
# 5                    0          1
# 6                    0          1
# 7                    0          0
# 8                    1          0
# 9                    0          0
# 10                   0          0

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 0)

# %%
# Feature Scaling because yes we don't want one independent variable dominating the other and it makes computations easy
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# sequential model to initialise our ann and dense module to build the layers
from keras.models import Sequential
from keras.layers import Dense

# %%
classifier = Sequential()
# Adding the input layer and the first hidden layer
classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 12))

# Adding the second hidden layer
classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))

# Adding the output layer
classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# Compiling the ANN | means applying SGD on the whole ANN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Fitting the ANN to the Training set
classifier.fit(X_train, y_train, batch_size = 10, epochs = 100,verbose = 1)
# Out:
# Epoch 1/100
# 670/670 [==============================] - 3s 2ms/step - loss: 0.5005 - accuracy: 0.7972
# Epoch 2/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4301 - accuracy: 0.7979
# Epoch 3/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4269 - accuracy: 0.7979
# Epoch 4/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4235 - accuracy: 0.7979
# Epoch 5/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4204 - accuracy: 0.8090
# Epoch 6/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4193 - accuracy: 0.8187
# Epoch 7/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4173 - accuracy: 0.8237
# Epoch 8/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4159 - accuracy: 0.8251
# Epoch 9/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4136 - accuracy: 0.8279
# Epoch 10/100
# 670/670 [==============================] - 2s 2ms/step - loss: 0.4130 - accuracy: 0.8279
# Epoch 11/100
# 670/670 [==============================] - 2s 2ms/step - loss: 0.4116 - accuracy: 0.8282
# Epoch 12/100
# 670/670 [==============================] - 2s 2ms/step - loss: 0.4111 - accuracy: 0.8310
# Epoch 13/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4102 - accuracy: 0.8324
# Epoch 14/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4094 - accuracy: 0.8319
# Epoch 15/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4087 - accuracy: 0.8319
# Epoch 16/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4077 - accuracy: 0.8336
# Epoch 17/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4072 - accuracy: 0.8333
# Epoch 18/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4066 - accuracy: 0.8339
# Epoch 19/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4055 - accuracy: 0.8334
# Epoch 20/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4054 - accuracy: 0.8343
# Epoch 21/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4053 - accuracy: 0.8340
# Epoch 22/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4046 - accuracy: 0.8346
# Epoch 23/100
# 670/670 [==============================] - 2s 2ms/step - loss: 0.4042 - accuracy: 0.8348
# Epoch 24/100
# 670/670 [==============================] - 2s 2ms/step - loss: 0.4039 - accuracy: 0.8337
# Epoch 25/100
# 670/670 [==============================] - 2s 2ms/step - loss: 0.4033 - accuracy: 0.8339
# Epoch 26/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4036 - accuracy: 0.8346
# Epoch 27/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4033 - accuracy: 0.8345
# Epoch 28/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4033 - accuracy: 0.8337
# Epoch 29/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4029 - accuracy: 0.8333
# Epoch 30/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4024 - accuracy: 0.8348
# Epoch 31/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4022 - accuracy: 0.8351
# Epoch 32/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4024 - accuracy: 0.8337
# Epoch 33/100
# 670/670 [==============================] - 2s 2ms/step - loss: 0.4020 - accuracy: 0.8357
# Epoch 34/100
# 670/670 [==============================] - 2s 2ms/step - loss: 0.4021 - accuracy: 0.8354
# Epoch 35/100
# 670/670 [==============================] - 2s 3ms/step - loss: 0.4019 - accuracy: 0.8345
# Epoch 36/100
# 670/670 [==============================] - 2s 2ms/step - loss: 0.4020 - accuracy: 0.8345
# Epoch 37/100
# 670/670 [==============================] - 2s 2ms/step - loss: 0.4018 - accuracy: 0.8342
# Epoch 38/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4018 - accuracy: 0.8334
# Epoch 39/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4017 - accuracy: 0.8351
# Epoch 40/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4012 - accuracy: 0.8343
# Epoch 41/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4009 - accuracy: 0.8351
# Epoch 42/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4013 - accuracy: 0.8348
# Epoch 43/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4013 - accuracy: 0.8348
# Epoch 44/100
# 670/670 [==============================] - 2s 2ms/step - loss: 0.4012 - accuracy: 0.8363
# Epoch 45/100
# 670/670 [==============================] - 2s 2ms/step - loss: 0.4007 - accuracy: 0.8342
# Epoch 46/100
# 670/670 [==============================] - 2s 2ms/step - loss: 0.4012 - accuracy: 0.8336
# Epoch 47/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4005 - accuracy: 0.8349
# Epoch 48/100
# 670/670 [==============================] - 2s 2ms/step - loss: 0.4007 - accuracy: 0.8334
# Epoch 49/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4009 - accuracy: 0.8337
# Epoch 50/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4006 - accuracy: 0.8343
# Epoch 51/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4007 - accuracy: 0.8358
# Epoch 52/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4003 - accuracy: 0.8334
# Epoch 53/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4002 - accuracy: 0.8354
# Epoch 54/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4005 - accuracy: 0.8349
# Epoch 55/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4002 - accuracy: 0.8367
# Epoch 56/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4004 - accuracy: 0.8357
# Epoch 57/100
# 670/670 [==============================] - 2s 2ms/step - loss: 0.4002 - accuracy: 0.8354
# Epoch 58/100
# 670/670 [==============================] - 2s 2ms/step - loss: 0.4005 - accuracy: 0.8337
# Epoch 59/100
# 670/670 [==============================] - 2s 2ms/step - loss: 0.4003 - accuracy: 0.8360
# Epoch 60/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4004 - accuracy: 0.8366
# Epoch 61/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4003 - accuracy: 0.8349
# Epoch 62/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4000 - accuracy: 0.8336
# Epoch 63/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4000 - accuracy: 0.8346
# Epoch 64/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4000 - accuracy: 0.8343
# Epoch 65/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4002 - accuracy: 0.8346
# Epoch 66/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4000 - accuracy: 0.8361
# Epoch 67/100
# 670/670 [==============================] - 2s 2ms/step - loss: 0.4001 - accuracy: 0.8346
# Epoch 68/100
# 670/670 [==============================] - 2s 2ms/step - loss: 0.3999 - accuracy: 0.8370
# Epoch 69/100
# 670/670 [==============================] - 2s 2ms/step - loss: 0.3999 - accuracy: 0.8357
# Epoch 70/100
# 670/670 [==============================] - 2s 2ms/step - loss: 0.4001 - accuracy: 0.8349
# Epoch 71/100
# 670/670 [==============================] - 2s 2ms/step - loss: 0.3996 - accuracy: 0.8364
# Epoch 72/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.4002 - accuracy: 0.8354
# Epoch 73/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.3997 - accuracy: 0.8357
# Epoch 74/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.3997 - accuracy: 0.8375
# Epoch 75/100
# 670/670 [==============================] - 2s 2ms/step - loss: 0.3997 - accuracy: 0.8370
# Epoch 76/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.3991 - accuracy: 0.8352
# Epoch 77/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.3998 - accuracy: 0.8361
# Epoch 78/100
# 670/670 [==============================] - 2s 2ms/step - loss: 0.3997 - accuracy: 0.8346
# Epoch 79/100
# 670/670 [==============================] - 2s 2ms/step - loss: 0.3999 - accuracy: 0.8352
# Epoch 80/100
# 670/670 [==============================] - 2s 2ms/step - loss: 0.3998 - accuracy: 0.8345
# Epoch 81/100
# 670/670 [==============================] - 2s 2ms/step - loss: 0.3996 - accuracy: 0.8361
# Epoch 82/100
# 670/670 [==============================] - 2s 2ms/step - loss: 0.3998 - accuracy: 0.8343
# Epoch 83/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.3996 - accuracy: 0.8343
# Epoch 84/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.3998 - accuracy: 0.8349
# Epoch 85/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.3993 - accuracy: 0.8354
# Epoch 86/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.3998 - accuracy: 0.8369
# Epoch 87/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.3992 - accuracy: 0.8364
# Epoch 88/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.3993 - accuracy: 0.8348
# Epoch 89/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.3998 - accuracy: 0.8360
# Epoch 90/100
# 670/670 [==============================] - 2s 2ms/step - loss: 0.3998 - accuracy: 0.8357
# Epoch 91/100
# 670/670 [==============================] - 2s 2ms/step - loss: 0.3996 - accuracy: 0.8354
# Epoch 92/100
# 670/670 [==============================] - 2s 2ms/step - loss: 0.3995 - accuracy: 0.8363
# Epoch 93/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.3991 - accuracy: 0.8372
# Epoch 94/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.3989 - accuracy: 0.8382
# Epoch 95/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.3994 - accuracy: 0.8342
# Epoch 96/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.3992 - accuracy: 0.8357
# Epoch 97/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.3992 - accuracy: 0.8351
# Epoch 98/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.3994 - accuracy: 0.8363
# Epoch 99/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.3992 - accuracy: 0.8366
# Epoch 100/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.3991 - accuracy: 0.8346

# %%
score, acc = classifier.evaluate(X_train, y_train,
                            batch_size=10)
print('Train score:', score)
print('Train accuracy:', acc)
# Part 3 - Making predictions and evaluating the model

# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)

print('*'*20)
score, acc = classifier.evaluate(X_test, y_test,
                            batch_size=10)
print('Test score:', score)
print('Test accuracy:', acc)
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
# Out:
# 670/670 [==============================] - 2s 2ms/step - loss: 0.3969 - accuracy: 0.8366
# Train score: 0.39691194891929626
# Train accuracy: 0.8365671634674072
# 104/104 [==============================] - 0s 2ms/step
# ********************
# 330/330 [==============================] - 1s 2ms/step - loss: 0.4009 - accuracy: 0.8421
# Test score: 0.40093398094177246
# Test accuracy: 0.8421211838722229

# %%
p = sns.heatmap(pd.DataFrame(cm), annot=True, cmap="YlGnBu" ,fmt='g')
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 20.049999999999997, 'Predicted label')

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.97      0.91      2617
#            1       0.76      0.35      0.48       683
#
#     accuracy                           0.84      3300
#    macro avg       0.80      0.66      0.69      3300
# weighted avg       0.83      0.84      0.82      3300

# %%
from sklearn.metrics import roc_curve
y_pred = classifier.predict(X_test)
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
plt.plot([0, 1], [0, 1], 'k--')
# ROC eğrisini çizmek için fpr ve tpr'yi kullanın
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
# Out:
# 104/104 [==============================] - 0s 2ms/step
# Text(0.5, 1.0, 'ROC Curve')

# %%
#Area under ROC curve
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test,y_pred)
# Out:
# 0.7966189645246673

# %%
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from keras.models import Sequential
from keras.layers import Dense
def build_classifier():
    classifier = Sequential()
    classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 12))
    classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
    classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
    classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
    return classifier
classifier = KerasClassifier(build_fn = build_classifier, batch_size = 10, epochs = 100,verbose=0)
accuracies = cross_val_score(estimator = classifier, X = X_train, y = y_train, cv = 10)
mean = accuracies.mean()
variance = accuracies.std()
# Out:
# C:\Users\ahmet\AppData\Local\Temp\ipykernel_13036\3352047426.py:12: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   classifier = KerasClassifier(build_fn = build_classifier, batch_size = 10, epochs = 100,verbose=0)

# %%
print('Mean accuracy score of 10 different models using Kfold cross validation: {}'.format(mean))
print('Standard Deviation of accuracy score of 10 different models using Kfold cross validation: {}'.format(variance))
# Out:
# Mean accuracy score of 10 different models using Kfold cross validation: 0.8356716454029083
# Standard Deviation of accuracy score of 10 different models using Kfold cross validation: 0.022222780244864102

# %%
# Improving the ANN
from keras.layers import Dropout
classifier = Sequential()
# Adding the input layer and the first hidden layer
classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 12))
classifier.add(Dropout(rate = 0.1))

# Adding the second hidden layer
classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
classifier.add(Dropout(rate = 0.1))

# Adding the output layer
classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# Compiling the ANN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Fitting the ANN to the Training set
classifier.fit(X_train, y_train, batch_size = 10, epochs = 100,verbose = 0)

# Part 3 - Making predictions and evaluating the model

score, acc = classifier.evaluate(X_train, y_train,
                            batch_size=10)
print('Train score:', score)
print('Train accuracy:', acc)
# Part 3 - Making predictions and evaluating the model

# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)

print('*'*20)
score, acc = classifier.evaluate(X_test, y_test,
                            batch_size=10)
print('Test score:', score)
print('Test accuracy:', acc)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
# Out:
# 670/670 [==============================] - 1s 2ms/step - loss: 0.3966 - accuracy: 0.8415
# Train score: 0.39655205607414246
# Train accuracy: 0.8414925336837769
# 104/104 [==============================] - 0s 1ms/step
# ********************
# 330/330 [==============================] - 1s 1ms/step - loss: 0.4002 - accuracy: 0.8406
# Test score: 0.40019407868385315
# Test accuracy: 0.8406060338020325

# %%
p = sns.heatmap(pd.DataFrame(cm), annot=True, cmap="YlGnBu" ,fmt='g')
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 20.049999999999997, 'Predicted label')

# %%
#import classification_report
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.97      0.91      2617
#            1       0.74      0.35      0.48       683
#
#     accuracy                           0.84      3300
#    macro avg       0.80      0.66      0.69      3300
# weighted avg       0.83      0.84      0.82      3300

# %%
from sklearn.metrics import roc_curve
y_pred = classifier.predict(X_test)
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr, label='ANN')
plt.xlabel('fpr')
plt.ylabel('tpr')
plt.title('ROC curve')
plt.show()
# Out:
# 104/104 [==============================] - 0s 2ms/step

# %%
#Area under ROC curve
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test,y_pred)
# Out:
# 0.8017562832499072

# %%
# Tuning the ANN
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
from keras.models import Sequential
from keras.layers import Dense
def build_classifier(optimizer):
    classifier = Sequential()
    classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 12))
    classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
    classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
    classifier.compile(optimizer = optimizer, loss = 'binary_crossentropy', metrics = ['accuracy'])
    return classifier
classifier = KerasClassifier(build_fn = build_classifier)
parameters = {'batch_size': [25, 32],
              'epochs': [100, 200],
              'optimizer': ['adam', 'rmsprop']}
grid_search = GridSearchCV(estimator = classifier,
                           param_grid = parameters,
                           scoring = 'accuracy',
                           cv = 10)
grid_search = grid_search.fit(X_train, y_train,verbose = 0)
best_parameters = grid_search.best_params_
best_accuracy = grid_search.best_score_
# Out:
# C:\Users\ahmet\AppData\Local\Temp\ipykernel_13036\3879786340.py:13: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   classifier = KerasClassifier(build_fn = build_classifier)
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 1ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 1ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 782us/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 554us/step
# 21/21 [==============================] - 0s 783us/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 0s 779us/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 1ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 1ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 781us/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 1ms/step
# 21/21 [==============================] - 0s 1ms/step
# 21/21 [==============================] - 0s 2ms/step

# %%
print('Best Parameters after tuning: {}'.format(best_parameters))
print('Best Accuracy after tuning: {}'.format(best_accuracy))
# Out:
# Best Parameters after tuning: {'batch_size': 25, 'epochs': 200, 'optimizer': 'adam'}
# Best Accuracy after tuning: 0.8467164179104477
